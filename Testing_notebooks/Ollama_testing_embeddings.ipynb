# %% [markdown]
# This is a test notebook to check the ollama working

# %% [markdown]
# ### Establishment of Ollama connection

# %%
import ollama

client = ollama.Client()
models = client.list()
print(models)
# Out:
# models=[Model(model='qwen2.5:7b', modified_at=datetime.datetime(2025, 10, 18, 13, 47, 35, 382191, tzinfo=TzInfo(+05:30)), digest='845dbda0ea48ed749caafd9e6037047aa19acfcfd82e704d7ca97d631a0b697e', size=4683087332, details=ModelDetails(parent_model='', format='gguf', family='qwen2', families=['qwen2'], parameter_size='7.6B', quantization_level='Q4_K_M')), Model(model='nomic-embed-text:latest', modified_at=datetime.datetime(2025, 10, 2, 23, 41, 33, 400355, tzinfo=TzInfo(+05:30)), digest='0a109f422b47e3a30ba2b10eca18548e944e8a23073ee3f3e947efcf3c45e59f', size=274302450, details=ModelDetails(parent_model='', format='gguf', family='nomic-bert', families=['nomic-bert'], parameter_size='137M', quantization_level='F16'))]

# %% [markdown]
# Lets check EMBEDDING

# %%
text = "UGC mandates anti-ragging committees in all HEIs."
response = ollama.embeddings(model="nomic-embed-text", prompt=text)

print(f"Embedding dim: {len(response['embedding'])}")
print(f"Values: {response['embedding']}")
# Out:
# Embedding dim: 768
# ...
