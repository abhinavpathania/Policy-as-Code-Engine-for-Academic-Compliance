# %%
import os
from pdf2image import convert_from_path
import pytesseract

# %%
def pdf_to_text(pdf_path):
    images = convert_from_path(pdf_path)
    text_all = []
    for i, img in enumerate(images):
        text = pytesseract.image_to_string(img)
        text_all.append(f"--- Page {i+1} ---\n{text.strip()}")
    return "\n".join(text_all)

# %%
def process_pdfs(input_dir, output_dir):
    os.makedirs(output_dir, exist_ok=True)
    for filename in os.listdir(input_dir):
        if filename.lower().endswith(".pdf"):
            pdf_path = os.path.join(input_dir, filename)
            print(f"Processing: {filename}")
            text = pdf_to_text(pdf_path)

            base_name = os.path.splitext(filename)[0]
            output_path = os.path.join(output_dir, f"{base_name}.txt")
            with open(output_path, "w", encoding="utf-8") as f:
                f.write(text)
            print(f"Saved OCR text: {output_path}")

# %%
#folder paths
input_folder = "../../Data"          # Folder with scanned PDFs
output_folder = "../../Data/Review"  # Folder to save text files

process_pdfs(input_folder, output_folder)
# Out:
# Processing: 10238.pdf
# Saved OCR text: ../../Data/Review\10238.txt
# Processing: 1713699_IDP-Guidelines.pdf
# Saved OCR text: ../../Data/Review\1713699_IDP-Guidelines.txt
# Processing: 1797652_Guidelines-for-PhD-Excellence-Citation.pdf
# Saved OCR text: ../../Data/Review\1797652_Guidelines-for-PhD-Excellence-Citation.txt
# Processing: 2025031399.pdf
# Saved OCR text: ../../Data/Review\2025031399.txt
# Processing: 2051511_Internship-Research-Internship-Guidelines.pdf
# Saved OCR text: ../../Data/Review\2051511_Internship-Research-Internship-Guidelines.txt
# Processing: 2998278_University-Grants-Commission-(Institutions-deemed-to-be-Universities)-Regulations,-2023.pdf
# Saved OCR text: ../../Data/Review\2998278_University-Grants-Commission-(Institutions-deemed-to-be-Universities)-Regulations,-2023.txt
# Processing: 4915310_Sustainable-and-Vibrant-University-Industry-Linkage-System.pdf
# Saved OCR text: ../../Data/Review\4915310_Sustainable-and-Vibrant-University-Industry-Linkage-System.txt
# Processing: 5018065_RPL-GUIDELINES.pdf
# Saved OCR text: ../../Data/Review\5018065_RPL-GUIDELINES.txt
# Processing: 6426821_SEDGs-Guidelines.pdf
# Saved OCR text: ../../Data/Review\6426821_SEDGs-Guidelines.txt
# Processing: 6493421_UGC-Guidelines-pursuing-two-academic-programmes-simultaneously.pdf
# Saved OCR text: ../../Data/Review\6493421_UGC-Guidelines-pursuing-two-academic-programmes-simultaneously.txt
# Processing: 7822003_GUIDELINES-ON-PUBLIC-SELF-DISCLOSURE-BY-HIGHER-EDUCATION-INSTITUTIONS.pdf
# Saved OCR text: ../../Data/Review\7822003_GUIDELINES-ON-PUBLIC-SELF-DISCLOSURE-BY-HIGHER-EDUCATION-INSTITUTIONS.txt
# Processing: 8273574_UGC-Guidelines-for-HEIs-to-Offer-Apprenticeship-Embedded-Degree-Programme-(AEDP).pdf
# Saved OCR text: ../../Data/Review\8273574_UGC-Guidelines-for-HEIs-to-Offer-Apprenticeship-Embedded-Degree-Programme-(AEDP).txt
# Processing: 9921822_Updated-SAARTHI-guidelines-2024.pdf
# Saved OCR text: ../../Data/Review\9921822_Updated-SAARTHI-guidelines-2024.txt
# Processing: AICTE Approval Process Handbook.pdf
# Saved OCR text: ../../Data/Review\AICTE Approval Process Handbook.txt
# Processing: AICTE Faculty Norms.pdf
# Saved OCR text: ../../Data/Review\AICTE Faculty Norms.txt
# Processing: AICTE Regulations – Grievance.pdf
# Saved OCR text: ../../Data/Review\AICTE Regulations – Grievance.txt
# Processing: AICTE-APPROVAL-PROCESS-HANDBOOK-2021-2022.pdf
# Saved OCR text: ../../Data/Review\AICTE-APPROVAL-PROCESS-HANDBOOK-2021-2022.txt
# Processing: AICTE-APPROVAL-PROCESS-HANDBOOK-2022-2023.pdf
# Saved OCR text: ../../Data/Review\AICTE-APPROVAL-PROCESS-HANDBOOK-2022-2023.txt
# Processing: AICTE-APPROVAL-PROCESS-HANDBOOK-2023-2024.pdf
# Saved OCR text: ../../Data/Review\AICTE-APPROVAL-PROCESS-HANDBOOK-2023-2024.txt
# Processing: AICTE-APPROVAL-PROCESS-HANDBOOK-2024-25-2025-26-2026-27.pdf
# Saved OCR text: ../../Data/Review\AICTE-APPROVAL-PROCESS-HANDBOOK-2024-25-2025-26-2026-27.txt
# Processing: Blockchain_For_Higher_Education_Reform_A_Strategic.pdf
# Saved OCR text: ../../Data/Review\Blockchain_For_Higher_Education_Reform_A_Strategic.txt
# Processing: Draft UGC Regulations 2025.pdf
# Saved OCR text: ../../Data/Review\Draft UGC Regulations 2025.txt
# Processing: DTBU_regulation_2023.pdf
# Saved OCR text: ../../Data/Review\DTBU_regulation_2023.txt
# Processing: GT-GLPP240042-1.pdf
# Saved OCR text: ../../Data/Review\GT-GLPP240042-1.txt
# Processing: IJRPR13650.pdf
# Saved OCR text: ../../Data/Review\IJRPR13650.txt
# Processing: press_release_ugc_net_june_2025.pdf
# Saved OCR text: ../../Data/Review\press_release_ugc_net_june_2025.txt
# Processing: public-notice-issuance-certificate-june-2025.pdf
# Saved OCR text: ../../Data/Review\public-notice-issuance-certificate-june-2025.txt
# Processing: regulation.pdf
# Saved OCR text: ../../Data/Review\regulation.txt
# Processing: UGC Autonomous College Regulations.pdf
# Saved OCR text: ../../Data/Review\UGC Autonomous College Regulations.txt
# Processing: UGC Guidelines - Examinations & Academic.pdf
# Saved OCR text: ../../Data/Review\UGC Guidelines - Examinations & Academic.txt
# Processing: UGC Guidelines for Students’ Entitlement.pdf
# Saved OCR text: ../../Data/Review\UGC Guidelines for Students’ Entitlement.txt
# Processing: UGC-Autonomous-College-Regulations-2023.pdf
# Saved OCR text: ../../Data/Review\UGC-Autonomous-College-Regulations-2023.txt
# Processing: UNI-D-2023-11-030949_MoARules_20240404164207445.pdf
# Saved OCR text: ../../Data/Review\UNI-D-2023-11-030949_MoARules_20240404164207445.txt
# Processing: UNI-D-2023-9-030814_MoARules_20240209162636166.pdf
# Saved OCR text: ../../Data/Review\UNI-D-2023-9-030814_MoARules_20240209162636166.txt
