# %%
import os
import ollama
import chromadb

# %%
import os
import ollama
import chromadb

def load_text_files(text_dir):
    """Load all .txt files from the directory."""
    texts = []
    for fname in os.listdir(text_dir):
        if fname.lower().endswith(".txt"):
            with open(os.path.join(text_dir, fname), "r", encoding="utf-8") as f:
                texts.append((fname, f.read()))
    return texts

def get_embedding(text, model="nomic-embed-text:latest"):
    """Generate embedding vector for text via Ollama."""
    response = ollama.embeddings(model=model, prompt=text)
    return response["embedding"]

def create_chroma_collection(client, collection_name="policy_docs"):
    """Create or get ChromaDB collection."""
    return client.get_or_create_collection(collection_name)

def embed_and_ingest(text_dir, chroma_path):
    # Initialize clients
    client = chromadb.PersistentClient(path=chroma_path)
    collection = create_chroma_collection(client)

    # Load texts
    documents = load_text_files(text_dir)

    ids = []
    embeddings = []
    metadatas = []
    documents_text = []

    for filename, content in documents:
        try:
            emb = get_embedding(content)
            ids.append(filename)
            embeddings.append(emb)
            metadatas.append({"source": filename})
            documents_text.append(content)
            print(f"Embedded and prepared document: {filename}")
        except Exception as e:
            print(f"Error embedding {filename}: {e}")

    # Store in ChromaDB
    collection.add(
        ids=ids,
        embeddings=embeddings,
        metadatas=metadatas,
        documents=documents_text
    )
    print(f"Stored {len(ids)} documents into ChromaDB at {chroma_path}")

if __name__ == "__main__":
    text_folder = "../../Data/CleanedText"
    chroma_db_folder = "../../Chroma_db_database"

    embed_and_ingest(text_folder, chroma_db_folder)
# Out:
# Embedded and prepared document: 10238.txt
# Embedded and prepared document: 1713699_IDP-Guidelines.txt
# Embedded and prepared document: 1797652_Guidelines-for-PhD-Excellence-Citation.txt
# Embedded and prepared document: 2025031399.txt
# Embedded and prepared document: 2051511_Internship-Research-Internship-Guidelines.txt
# Embedded and prepared document: 2998278_University-Grants-Commission-(Institutions-deemed-to-be-Universities)-Regulations,-2023.txt
# Embedded and prepared document: 4915310_Sustainable-and-Vibrant-University-Industry-Linkage-System.txt
# Embedded and prepared document: 5018065_RPL-GUIDELINES.txt
# Embedded and prepared document: 6426821_SEDGs-Guidelines.txt
# Embedded and prepared document: 6493421_UGC-Guidelines-pursuing-two-academic-programmes-simultaneously.txt
# Embedded and prepared document: 7822003_GUIDELINES-ON-PUBLIC-SELF-DISCLOSURE-BY-HIGHER-EDUCATION-INSTITUTIONS.txt
# Embedded and prepared document: 8273574_UGC-Guidelines-for-HEIs-to-Offer-Apprenticeship-Embedded-Degree-Programme-(AEDP).txt
# Embedded and prepared document: 9921822_Updated-SAARTHI-guidelines-2024.txt
# Embedded and prepared document: AICTE Approval Process Handbook.txt
# Embedded and prepared document: AICTE Faculty Norms.txt
# Embedded and prepared document: AICTE Regulations – Grievance.txt
# Embedded and prepared document: AICTE-APPROVAL-PROCESS-HANDBOOK-2021-2022.txt
# Embedded and prepared document: AICTE-APPROVAL-PROCESS-HANDBOOK-2022-2023.txt
# Embedded and prepared document: AICTE-APPROVAL-PROCESS-HANDBOOK-2023-2024.txt
# Embedded and prepared document: AICTE-APPROVAL-PROCESS-HANDBOOK-2024-25-2025-26-2026-27.txt
# Embedded and prepared document: Blockchain_For_Higher_Education_Reform_A_Strategic.txt
# Embedded and prepared document: Draft UGC Regulations 2025.txt
# Embedded and prepared document: DTBU_regulation_2023.txt
# Embedded and prepared document: GT-GLPP240042-1.txt
# Embedded and prepared document: IJRPR13650.txt
# Embedded and prepared document: press_release_ugc_net_june_2025.txt
# Embedded and prepared document: public-notice-issuance-certificate-june-2025.txt
# Embedded and prepared document: regulation.txt
# Embedded and prepared document: UGC Autonomous College Regulations.txt
# Embedded and prepared document: UGC Guidelines - Examinations & Academic.txt
# Embedded and prepared document: UGC Guidelines for Students’ Entitlement.txt
# Embedded and prepared document: UGC-Autonomous-College-Regulations-2023.txt
# Embedded and prepared document: UNI-D-2023-11-030949_MoARules_20240404164207445.txt
# Embedded and prepared document: UNI-D-2023-9-030814_MoARules_20240209162636166.txt
# Stored 34 documents into ChromaDB at ../../Chroma_db_database
