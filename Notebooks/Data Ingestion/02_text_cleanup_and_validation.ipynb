# %%
import os

# %%
def simple_cleanup(text):
    # Example: remove excessive newlines
    return "\n".join(line.strip() for line in text.splitlines() if line.strip())

# %%
def batch_cleanup(input_dir, output_dir):
    os.makedirs(output_dir, exist_ok=True)
    for fname in os.listdir(input_dir):
        if fname.lower().endswith(".txt"):
            with open(os.path.join(input_dir, fname), "r", encoding="utf-8") as f:
                raw_text = f.read()
            cleaned = simple_cleanup(raw_text)
            with open(os.path.join(output_dir, fname), "w", encoding="utf-8") as f:
                f.write(cleaned)
            print(f"Cleaned and saved: {fname}")

# %%
# Parameters: paths to be adjusted
raw_text_folder = "../../Data/Review"
clean_text_folder = "../../Data/CleanedText"

batch_cleanup(raw_text_folder, clean_text_folder)
# Out:
# Cleaned and saved: 10238.txt
# Cleaned and saved: 1713699_IDP-Guidelines.txt
# Cleaned and saved: 1797652_Guidelines-for-PhD-Excellence-Citation.txt
# Cleaned and saved: 2025031399.txt
# Cleaned and saved: 2051511_Internship-Research-Internship-Guidelines.txt
# Cleaned and saved: 2998278_University-Grants-Commission-(Institutions-deemed-to-be-Universities)-Regulations,-2023.txt
# Cleaned and saved: 4915310_Sustainable-and-Vibrant-University-Industry-Linkage-System.txt
# Cleaned and saved: 5018065_RPL-GUIDELINES.txt
# Cleaned and saved: 6426821_SEDGs-Guidelines.txt
# Cleaned and saved: 6493421_UGC-Guidelines-pursuing-two-academic-programmes-simultaneously.txt
# Cleaned and saved: 7822003_GUIDELINES-ON-PUBLIC-SELF-DISCLOSURE-BY-HIGHER-EDUCATION-INSTITUTIONS.txt
# Cleaned and saved: 8273574_UGC-Guidelines-for-HEIs-to-Offer-Apprenticeship-Embedded-Degree-Programme-(AEDP).txt
# Cleaned and saved: 9921822_Updated-SAARTHI-guidelines-2024.txt
# Cleaned and saved: AICTE Approval Process Handbook.txt
# Cleaned and saved: AICTE Faculty Norms.txt
# Cleaned and saved: AICTE Regulations – Grievance.txt
# Cleaned and saved: AICTE-APPROVAL-PROCESS-HANDBOOK-2021-2022.txt
# Cleaned and saved: AICTE-APPROVAL-PROCESS-HANDBOOK-2022-2023.txt
# Cleaned and saved: AICTE-APPROVAL-PROCESS-HANDBOOK-2023-2024.txt
# Cleaned and saved: AICTE-APPROVAL-PROCESS-HANDBOOK-2024-25-2025-26-2026-27.txt
# Cleaned and saved: Blockchain_For_Higher_Education_Reform_A_Strategic.txt
# Cleaned and saved: Draft UGC Regulations 2025.txt
# Cleaned and saved: DTBU_regulation_2023.txt
# Cleaned and saved: GT-GLPP240042-1.txt
# Cleaned and saved: IJRPR13650.txt
# Cleaned and saved: press_release_ugc_net_june_2025.txt
# Cleaned and saved: public-notice-issuance-certificate-june-2025.txt
# Cleaned and saved: regulation.txt
# Cleaned and saved: UGC Autonomous College Regulations.txt
# Cleaned and saved: UGC Guidelines - Examinations & Academic.txt
# Cleaned and saved: UGC Guidelines for Students’ Entitlement.txt
# Cleaned and saved: UGC-Autonomous-College-Regulations-2023.txt
# Cleaned and saved: UNI-D-2023-11-030949_MoARules_20240404164207445.txt
# Cleaned and saved: UNI-D-2023-9-030814_MoARules_20240209162636166.txt
